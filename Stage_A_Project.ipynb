# %% [markdown]
# <a href="https://colab.research.google.com/github/michael-samuel2306/HDSC-Winter2023-Projects/blob/main/Stage_A_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TAG ALONG PROJECT ON INTRODUCTION TO PYTHON FOR MACHINE LEARNING

# %% [markdown]
# ## Michael John Samuel
# ## ID: 163c0e380141f000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
food_data = pd.read_csv("/content/FoodBalanceSheets_E_Africa_NOFLAG (1).csv", encoding = 'latin-1')
food_data.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
food_data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
food_data.dropna()
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
food_data.duplicated().any()
# Out:
# False

# %%
food_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
food_data.groupby("Element")['Y2017'].sum()
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %%
food_data.groupby("Element").sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
food_data.groupby('Area').sum()
# Out:
#                              Area Code  Item Code  Element Code       Y2014  \
# Area
# Algeria                           5252    3532053       5017927   313375.33
# Angola                            9968    3819908       5515088   208584.42
# Benin                            68105    3453692       4852820   118050.79
# Botswana                         27560    3704902       5259784    22339.92
# Burkina Faso                    328297    3778795       5431243   105051.33
# Cabo Verde                       44100    3396746       4787751    14576.94
# Cameroon                         46720    3916078       5663196   217630.28
# Central African Republic         49728    3607546       5069094    28739.02
# Chad                             52377    3606529       5108355    65940.17
# Comoros                           2025     124514        241681       32.00
# Congo                            64998    3792029       5445560    38699.26
# ...

# %%
food_data.groupby('Area').count().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, Algeria to Zimbabwe
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     49 non-null     int64
#  1   Item Code     49 non-null     int64
#  2   Item          49 non-null     int64
#  3   Element Code  49 non-null     int64
#  4   Element       49 non-null     int64
#  5   Unit          49 non-null     int64
#  6   Y2014         49 non-null     int64
#  7   Y2015         49 non-null     int64
#  8   Y2016         49 non-null     int64
#  9   Y2017         49 non-null     int64
#  10  Y2018         49 non-null     int64
# dtypes: int64(11)
# memory usage: 4.6+ KB

# %%
food_data.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
food_data.groupby("Area")[['Y2017','Area']].count()
# Out:
#                              Y2017  Area
# Area
# Algeria                       1279  1313
# Angola                        1407  1424
# Benin                         1253  1285
# Botswana                      1368  1378
# Burkina Faso                  1383  1409
# Cabo Verde                    1193  1260
# Cameroon                      1441  1460
# Central African Republic      1262  1344
# Chad                          1281  1343
# Comoros                         45    45
# Congo                         1395  1413
# Côte d'Ivoire                 1454  1467
# Djibouti                      1061  1095
# Egypt                         1458  1488
# Eswatini                      1251  1284
# Ethiopia                      1428  1447
# Ethiopia PDR                    39    39
# Gabon                         1206  1245
# Gambia                        1116  1168
# Ghana                         1333  1354
# Guinea                        1383  1410
# Guinea-Bissau                 1076  1128
# ...

# %%
food_data.groupby("Element")['Y2017'].mean()
# Out:
# Element
# Domestic supply quantity                    397.146843
# Export Quantity                              49.819344
# Fat supply quantity (g/capita/day)            2.058177
# Feed                                        184.423479
# Food                                        256.288331
# Food supply (kcal/capita/day)                91.577241
# Food supply quantity (kg/capita/yr)           9.985652
# Import Quantity                              59.760416
# Losses                                       79.947237
# Other uses (non-food)                        56.606529
# Processing                                  146.564565
# Production                                  530.179391
# Protein supply quantity (g/capita/day)        2.378002
# Residuals                                     7.687311
# Seed                                         32.810211
# Stock Variation                              12.837842
# Total Population - Both sexes             24725.355556
# ...

# %%
food_data['Y2017'].describe()
# Out:
# count     59437.000000
# mean        140.917765
# std        1671.862359
# min       -1582.000000
# 25%           0.000000
# 50%           0.100000
# 75%           9.000000
# max      190873.000000
# Name: Y2017, dtype: float64

# %%
food_data.groupby('Item').count()
# Out:
#                      Area Code  Area  Item Code  Element Code  Element  Unit  \
# Item
# Alcohol, Non-Food          283   283        283           283      283   283
# Alcoholic Beverages        564   564        564           564      564   564
# Animal Products            135   135        135           135      135   135
# Animal fats                639   639        639           639      639   639
# Apples and products        517   517        517           517      517   517
# ...                        ...   ...        ...           ...      ...   ...
# Vegetables, Other          583   583        583           583      583   583
# Vegetal Products           135   135        135           135      135   135
# Wheat and products         653   653        653           653      653   653
# Wine                       497   497        497           497      497   497
# Yams                       383   383        383           383      383   383
#
# ...
